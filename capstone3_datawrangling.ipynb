# %%
"""
This project is my third capstone. I intend to create a machine learning model that will predict the price of Amazon stock. 

Step 1. is data sourcing. I plan to download the majority of data through yahoo finance. I intend to download directly using API
functions whenever possible. The data I am looking to download is:
    All the information will be from November 1 2020 to May 30, 2023
    Amazon stock price *-
    Amazon Earnings Report
    Dow *-
    Nasdaq *-
    QQQ *-
    S&P 500 *-
    Google *-
    Apple *-
    Inflation rates *
    interest rates *
    price of oil*
    Buy/Sell ratings
    GDP Growth *
    Employment Data *
    Technical Data
        RSI(Relative Strength Index)
        Bollinger Bands
        MACD
    Social Media sentiment

Step 2. Will be to join all the data onto a dataframe and clean up the data.

Step 3 Do some initial analysis on the Data Frame

Step 4 Run the Data frame through many Machine learning algorithms

Step 5 Analysis on the ML algorithms and compare results.

Step 6 Discuss results and discuss next steps.
"""
# Out:
# '\nThis project is my third capstone. I intend to create a machine learning model that will predict the price of Amazon stock. \n\nStep 1. is data sourcing. I plan to download the majority of data through yahoo finance. I intend to download directly using API\nfunctions whenever possible. The data I am looking to download is:\n    All the information will be from November 1 2020 to May 30, 2023\n    Amazon stock price *-\n    Amazon Earnings Report\n    Dow *-\n    Nasdaq *-\n    QQQ *-\n    S&P 500 *-\n    Google *-\n    Apple *-\n    Inflation rates *\n    interest rates *\n    price of oil*\n    Buy/Sell ratings\n    GDP Growth *\n    Employment Data *\n    Technical Data\n        RSI(Relative Strength Index)\n        Bollinger Bands\n        MACD\n    Social Media sentiment\n\nStep 2. Will be to join all the data onto a dataframe and clean up the data.\n\nStep 3 Do some initial analysis on the Data Frame\n\nStep 4 Run the Data frame through many Machine learning algorithms\n\nSte
# ...

# %%
import pandas as pd
import yfinance as yf
from yahoofinancials import YahooFinancials

# %%
import datetime
startdate = datetime.datetime(2020, 1, 1)
enddate = datetime.datetime(2023, 5, 30)

# %%
stocks = ['AMZN']
other_stocks = ['GOOGL', 'AAPL', 'QQQ', 'DIA', 'ONEQ', 'VOO']

# %%
df_amzn = yf.download(tickers = stocks, start = startdate, end = enddate, group_by = 'ticker',  )
df_amzn = df_amzn.add_prefix(stocks[0]+ ' ')
df_amzn.reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
#           Date   AMZN Open   AMZN High    AMZN Low  AMZN Close  \
# 0   2020-01-02   93.750000   94.900497   93.207497   94.900497
# 1   2020-01-03   93.224998   94.309998   93.224998   93.748497
# 2   2020-01-06   93.000000   95.184502   93.000000   95.143997
# 3   2020-01-07   95.224998   95.694504   94.601997   95.343002
# 4   2020-01-08   94.902000   95.550003   94.321999   94.598503
# ..         ...         ...         ...         ...         ...
# 852 2023-05-22  116.769997  116.769997  114.250000  115.010002
# 853 2023-05-23  114.269997  117.139999  113.779999  114.989998
# 854 2023-05-24  115.349998  117.339996  115.019997  116.750000
# 855 2023-05-25  116.629997  116.870003  114.309998  115.000000
# 856 2023-05-26  116.040001  121.500000  116.019997  120.110001
#
#      AMZN Adj Close  AMZN Volume
# 0         94.900497     80580000
# 1         93.748497     75288000
# 2         95.143997     81236000
# ...

# %%
stock = 'GOOGL'
df_google = yf.download(tickers = stock, start = startdate, end = enddate, group_by = 'ticker',  )
df_google = df_google.add_prefix(stock + ' ')
df_google.reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
#           Date  GOOGL Open  GOOGL High   GOOGL Low  GOOGL Close  \
# 0   2020-01-02   67.420502   68.433998   67.324501    68.433998
# 1   2020-01-03   67.400002   68.687500   67.365997    68.075996
# 2   2020-01-06   67.581497   69.916000   67.550003    69.890503
# 3   2020-01-07   70.023003   70.175003   69.578003    69.755501
# 4   2020-01-08   69.740997   70.592499   69.631500    70.251999
# ..         ...         ...         ...         ...          ...
# 852 2023-05-22  122.940002  126.430000  122.739998   125.050003
# 853 2023-05-23  124.160004  124.629997  122.209999   122.559998
# 854 2023-05-24  121.120003  121.910004  119.860001   120.900002
# 855 2023-05-25  124.519997  125.320000  121.959999   123.480003
# 856 2023-05-26  123.169998  125.260002  122.449997   124.610001
#
#      GOOGL Adj Close  GOOGL Volume
# 0          68.433998      27278000
# 1          68.075996      23408000
# ...

# %%
stock = 'AAPL'
df_apple = yf.download(tickers = stock, start = startdate, end = enddate, group_by = 'ticker',  )
df_apple = df_apple.add_prefix(stock + ' ')
df_apple.reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
#           Date   AAPL Open   AAPL High    AAPL Low  AAPL Close  \
# 0   2020-01-02   74.059998   75.150002   73.797501   75.087502
# 1   2020-01-03   74.287498   75.144997   74.125000   74.357498
# 2   2020-01-06   73.447502   74.989998   73.187500   74.949997
# 3   2020-01-07   74.959999   75.224998   74.370003   74.597504
# 4   2020-01-08   74.290001   76.110001   74.290001   75.797501
# ..         ...         ...         ...         ...         ...
# 852 2023-05-22  173.979996  174.710007  173.449997  174.199997
# 853 2023-05-23  173.130005  173.380005  171.279999  171.559998
# 854 2023-05-24  171.089996  172.419998  170.520004  171.839996
# 855 2023-05-25  172.410004  173.899994  171.690002  172.990005
# 856 2023-05-26  173.320007  175.770004  173.110001  175.429993
#
#      AAPL Adj Close  AAPL Volume
# 0         73.347946    135480400
# 1         72.634834    146322800
# 2         73.213631    118387200
# ...

# %%
stock = 'QQQ'
df_qqq = yf.download(tickers = stock, start = startdate, end = enddate, group_by = 'ticker',  )
df_qqq = df_qqq.add_prefix(stock + ' ')
df_qqq.reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
#           Date    QQQ Open    QQQ High     QQQ Low   QQQ Close  QQQ Adj Close  \
# 0   2020-01-02  214.399994  216.160004  213.979996  216.160004     211.722275
# 1   2020-01-03  213.300003  215.470001  213.279999  214.179993     209.782883
# 2   2020-01-06  212.500000  215.589996  212.240005  215.559998     211.134598
# 3   2020-01-07  215.639999  216.139999  214.850006  215.529999     211.105194
# 4   2020-01-08  215.500000  218.139999  215.160004  217.149994     212.691925
# ..         ...         ...         ...         ...         ...            ...
# 852 2023-05-22  336.250000  338.670013  336.239990  337.640015     337.177490
# 853 2023-05-23  335.890015  337.059998  333.000000  333.359985     332.903351
# 854 2023-05-24  331.369995  332.910004  329.559998  331.649994     331.195679
# 855 2023-05-25  339.140015  341.010010  336.670013  339.720001     339.254639
# ...

# %%
stock = 'DIA'
df_dia = yf.download(tickers = stock, start = startdate, end = enddate, group_by = 'ticker',  )
df_dia = df_dia.add_prefix(stock + ' ')
df_dia.reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
#           Date    DIA Open    DIA High     DIA Low   DIA Close  DIA Adj Close  \
# 0   2020-01-02  286.440002  288.630005  286.149994  288.619995     269.686523
# 1   2020-01-03  285.339996  287.109985  285.179993  286.320007     267.537354
# 2   2020-01-06  284.290009  287.029999  284.160004  286.980011     268.154053
# 3   2020-01-07  286.299988  286.790009  285.579987  285.739990     266.995514
# 4   2020-01-08  285.320007  288.670013  285.079987  287.399994     268.546631
# ..         ...         ...         ...         ...         ...            ...
# 852 2023-05-22  334.119995  335.149994  332.019989  332.899994     332.150696
# 853 2023-05-23  331.760010  333.100006  330.079987  330.609985     329.865845
# 854 2023-05-24  330.000000  330.239990  327.480011  328.010010     327.271729
# 855 2023-05-25  328.070007  328.730011  325.820007  327.750000     327.012299
# ...

# %%
stock = 'ONEQ'
df_oneq = yf.download(tickers = stock, start = startdate, end = enddate, group_by = 'ticker',  )
df_oneq = df_oneq.add_prefix(stock + ' ')
df_oneq.reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
#           Date  ONEQ Open  ONEQ High   ONEQ Low  ONEQ Close  ONEQ Adj Close  \
# 0   2020-01-02  35.226002  35.380001  35.040001   35.380001       34.403355
# 1   2020-01-03  35.097000  35.310001  35.049999   35.200001       34.228329
# 2   2020-01-06  35.174000  35.311001  34.848999   35.310001       34.335297
# 3   2020-01-07  35.310001  35.403000  35.205002   35.300999       34.326534
# 4   2020-01-08  35.248001  35.740002  35.248001   35.500999       34.521011
# ..         ...        ...        ...        ...         ...             ...
# 852 2023-05-22  49.730000  50.090000  49.730000   49.970001       49.886871
# 853 2023-05-23  49.770000  49.910000  49.299999   49.340000       49.257919
# 854 2023-05-24  48.980000  49.189999  48.759998   48.980000       48.898518
# 855 2023-05-25  49.900002  50.020000  49.490002   49.840000       49.757088
# ...

# %%
stock = 'VOO'
df_voo = yf.download(tickers = stock, start = startdate, end = enddate, group_by = 'ticker',  )
df_voo = df_voo.add_prefix(stock + ' ')
df_voo.reset_index()
# Out:
# [*********************100%***********************]  1 of 1 completed
#           Date    VOO Open    VOO High     VOO Low   VOO Close  VOO Adj Close  \
# 0   2020-01-02  297.290009  298.450012  296.339996  298.420013     281.972473
# 1   2020-01-03  295.220001  297.359985  295.040009  296.239990     279.912598
# 2   2020-01-06  294.420013  297.420013  294.350006  297.350006     280.961456
# 3   2020-01-07  296.820007  297.269989  296.059998  296.529999     280.186646
# 4   2020-01-08  296.709991  299.309998  296.470001  298.059998     281.632263
# ..         ...         ...         ...         ...         ...            ...
# 852 2023-05-22  384.660004  386.230011  383.470001  384.779999     383.273560
# 853 2023-05-23  383.190002  384.109985  380.079987  380.480011     378.990417
# 854 2023-05-24  378.910004  379.250000  376.570007  377.630005     376.151550
# 855 2023-05-25  380.989990  382.279999  378.920013  380.920013     379.428680
# ...

# %%
df_frames = [df_google, df_apple, df_qqq, df_dia, df_oneq, df_voo, df_amzn]
df = pd.concat(df_frames, axis = 1)
df.reset_index()
# Out:
#           Date  GOOGL Open  GOOGL High   GOOGL Low  GOOGL Close  \
# 0   2020-01-02   67.420502   68.433998   67.324501    68.433998
# 1   2020-01-03   67.400002   68.687500   67.365997    68.075996
# 2   2020-01-06   67.581497   69.916000   67.550003    69.890503
# 3   2020-01-07   70.023003   70.175003   69.578003    69.755501
# 4   2020-01-08   69.740997   70.592499   69.631500    70.251999
# ..         ...         ...         ...         ...          ...
# 852 2023-05-22  122.940002  126.430000  122.739998   125.050003
# 853 2023-05-23  124.160004  124.629997  122.209999   122.559998
# 854 2023-05-24  121.120003  121.910004  119.860001   120.900002
# 855 2023-05-25  124.519997  125.320000  121.959999   123.480003
# 856 2023-05-26  123.169998  125.260002  122.449997   124.610001
#
#      GOOGL Adj Close  GOOGL Volume   AAPL Open   AAPL High    AAPL Low  ...  \
# 0          68.433998      27278000   74.059998   75.150002   73.797501  ...
# ...

# %%
import os

path = r'C:\\Capstone3\\'

# %%
listoffiles = ['IXIC', 'Daily Treasury Bill Rates Final', 'daily_treasure_real_long_rates_final', 'daily_treasury_curve_rate_final', 'Employment_Rate',
           'GDP', 'Par Yield Curve Rates Final', 'PET_PRI_SPT_S1_D']
dataframes_list = []
for i in range(len(listoffiles)):
    temp_df = pd.read_csv(path + listoffiles[i] + '.csv')
    dataframes_list.append(temp_df)

# %%
temp = dataframes_list
df1 = dataframes_list[0]
del temp[0]

# %%
for i in temp:
    df1 = df1.merge(i, on = 'Date', how = 'left')

# %%
df1['Date']=df1['Date'].astype('datetime64')

# %%
df_final = df1.merge(df, on = 'Date', how = 'left')

# %%
# Although this data is readily available, I wanted to create the bands to practice.
def bollinger_bands(stock_df):
    import numpy as np
    import pandas as pd
    import matplotlib as plt
    
    df = stock_df[['AMZN Adj Close']]
  
    
    # Create rolling average and standard deviation
    sma = df.rolling(window=20).mean().dropna()
    
    rstd = df.rolling(window=20).std().dropna()
    # Create upper band and lower bands
    upper_band = sma + 2*rstd
    lower_band = sma - 2*rstd

    #Create columns with upper and lower band data
    upper_band = upper_band.rename(columns = {'AMZN Adj Close': 'Upper BB'})
    lower_band = lower_band.rename(columns = {'AMZN Adj Close': 'Lower BB'})
    bb = df.join(sma, rsuffix = 'SMA')
    bb = bb.join(upper_band).join(lower_band)
    bb = bb.dropna()
         
    bb.columns = ['AMZN Adj Close', 'SMA', 'BB Upper Band', 'BB Lower Band']
    band_conditions = [
        (bb['SMA'] >= bb['BB Upper Band']),
        (bb['SMA'] < bb['BB Upper Band']) & (bb['SMA']> bb['BB Lower Band']),
        (bb['SMA'] <= bb['BB Lower Band'])
    ]
    band_categories = ['Overbought', 'In Range', 'Oversold']
    bb['Bollinger_Status'] = np.select(band_conditions, band_categories)
    bb = bb.drop(['AMZN Adj Close'], axis = 1)
    return bb
    
 
bollinger_data = bollinger_bands(df_amzn)

# %%
df = df_final.merge(bollinger_data, on = 'Date', how = 'left')

# %%
def MACD(stock_df):
    import numpy as np
    k = stock_df['AMZN Adj Close'].ewm(span = 12, adjust = False, min_periods=12).mean()
    d = stock_df['AMZN Adj Close'].ewm(span=26, adjust = False, min_periods = 26).mean()
    macd = k-d
    macd_trigger =  macd.ewm(span = 9, adjust = False, min_periods = 9).mean()
    macd_c_d = macd - macd_trigger
    df_macd = pd.concat([macd, macd_trigger, macd_c_d], axis = 1)
    df_macd.columns =  ['MACD', 'MACD_Trigger', 'MACD_Con/Div']
    
    macd_conditions = [
        (df_macd['MACD_Con/Div'] > 0),
        (df_macd['MACD_Con/Div'] < 0)
    ]
    macd_categories = ['Bullish', 'Bearish']
    df_macd['MACD_Market'] = np.select(macd_conditions, macd_categories)
    df_macd = df_macd.dropna()
    return df_macd
    
    
df_macd = MACD(df_amzn)

# %%
df = df.merge(df_macd, on = 'Date', how = 'left')
df
# Out:
#           Date     IXIC Open     IXIC High      IXIC Low    IXIC Close  \
# 0   2020-01-02   9039.459961   9093.429688   9010.889648   9092.190430
# 1   2020-01-03   8976.429688   9065.759766   8976.429688   9020.769531
# 2   2020-01-06   8943.500000   9072.410156   8943.500000   9071.469727
# 3   2020-01-07   9076.639648   9091.929688   9042.549805   9068.580078
# 4   2020-01-08   9068.030273   9168.889648   9059.379883   9129.240234
# ..         ...           ...           ...           ...           ...
# 852 2023-05-22  12664.440430  12756.230470  12655.259770  12720.780270
# 853 2023-05-23  12652.879880  12709.740230  12554.429690  12560.250000
# 854 2023-05-24  12481.889650  12529.629880  12415.849610  12484.160160
# 855 2023-05-25  12706.440430  12736.919920  12604.889650  12698.089840
# 856 2023-05-26  12736.419920  13001.910160  12729.740230  12975.690430
#
#      IXIC Adj Close  4 WEEKS BANK DISCOUNT  4 WEEKS COUPON EQUIVALENT  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'IXIC Open', 'IXIC High', 'IXIC Low', 'IXIC Close',
#        'IXIC Adj Close', '4 WEEKS BANK DISCOUNT', '4 WEEKS COUPON EQUIVALENT',
#        '8 WEEKS BANK DISCOUNT', '8 WEEKS COUPON EQUIVALENT',
#        '13 WEEKS BANK DISCOUNT', '13 WEEKS COUPON EQUIVALENT',
#        '26 WEEKS BANK DISCOUNT', '26 WEEKS COUPON EQUIVALENT',
#        '52 WEEKS BANK DISCOUNT', '52 WEEKS COUPON EQUIVALENT',
#        'LT Real Average (10> Yrs)', '5 YR', '7 YR', '10 YR', '20 YR', '30 YR',
#        '% employed', 'GDP', '1 Mo', '2 Mo', '3 Mo', '6 Mo', '1 Yr', '2 Yr',
#        '3 Yr', '5 Yr', '7 Yr', '10 Yr', '20 Yr', '30 Yr',
#        'Cushing, OK WTI Spot Price FOB (Dollars per Barrel)',
#        'Europe Brent Spot Price FOB (Dollars per Barrel)', 'GOOGL Open',
#        'GOOGL High', 'GOOGL Low', 'GOOGL Close', 'GOOGL Adj Close',
#        'GOOGL Volume', 'AAPL Open', 'AAPL High', 'AAPL Low', 'AAPL Close',
#        'AAPL Adj Close', 'AAPL Volume', 'QQQ Open', 'QQQ High', 'QQQ Low',
# ...

# %%
# Sentiment analysis for Amazon stock
def Sentiment_stock(stock):
    import os
    import matplotlib.pyplot as plt
    from bs4 import BeautifulSoup
    import pandas as pd
    import nltk
    from urllib.request import urlopen, Request
    from nltk.sentiment.vader import SentimentIntensityAnalyzer
    
    news_tables = {}
    url = 'https://finviz.com/quote.ashx?t='
    full_url = url + stock
    req = Request(url = full_url, headers = {"User-Agent": "Chrome"})
    response = urlopen(req)
    html = BeautifulSoup(response, 'html.parser')
    news_table = html.find(id = 'news-table')
    news_tables[stock] = news_table
    
    amzn = news_tables[stock]
    amzn_tr = amzn.findAll('tr')
    
    for x, table_row in enumerate(amzn_tr):
        a_text = table_row.a.text
        td_text = table_row.td.text
        if x == 3:
            break
    news_list = []
    for file_name, news_table in news_tables.items():
        for i in news_table.find_all('tr'):
            text = i.get_text()
            date_scrape = i.td.text.split()
            if len(date_scrape) == 1:
                time = date_scrape[0]
            else:
                date = date_scrape[0]
                time = date_scrape[1]
            tick = file_name.split('_')[0]
            
            news_list.append([tick, date, time, text])
            
    vader = SentimentIntensityAnalyzer()
    columns = ['ticker', 'date', 'time', 'headline']
    news_df = pd.DataFrame(news_list, columns = columns)
    scores = news_df['headline'].apply(vader.polarity_scores).tolist()
    scores_df = pd.DataFrame(scores)
    news_df = news_df.join(scores_df, rsuffix = '_right')
    news_df['date'] = pd.to_datetime(news_df.date).dt.date
    day_score_df = news_df.groupby(['date']).agg({'compound': 'mean'}).reset_index()
    return day_score_df
    

day_score_df = Sentiment_stock('AMZN')

# %%
day_score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   date      7 non-null      object
#  1   compound  7 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 240.0+ bytes

# %%
def RSI(stock_df, lower, upper):
    # This function will take amazon stock and return a Relative String Index data to be added to the main dataframe.
    import numpy as np
    df = stock_df[['AMZN Adj Close']]
    
    change = df['AMZN Adj Close'].diff()
    low = lower
    high = upper
    up = change.copy()
    down = change.copy()
    up[up<0] = 0
    down[down>0] = 0
    
    avg_up = up.rolling(14).mean()
    avg_dwn = down.rolling(14).mean().abs()
    
    rsi = 100 * avg_up / (avg_up + avg_dwn)
    df_s = [df, rsi]
    df = pd.concat(df_s, axis = 1)
    df.reset_index()
    df.columns= ['AMZN Adj Close', 'RSI']
    rsi_conditions = [
        (df['RSI'] > high),
        (df['RSI']<= high) & (df['RSI'] >= low),
        (df['RSI'] < low)
    ]
    rsi_categories = ['Bullish', 'Normal', 'Bearish']
    df['RSI_Status'] = np.select(rsi_conditions, rsi_categories)
    df = df.dropna()
    df = df.drop(['AMZN Adj Close'], axis = 1)
    final = [df, low, high]
    
    return final
df_RSI = RSI(df_amzn, 30,70)

# %%
df = df.merge(df_RSI[0], on = 'Date', how = 'left')

# %%
def bollinger_graphs(bollinger_data):
    #To plot bollinger plots using bollinger data

# %%
def MACD_graphs(df_macd):
    #To plot bollinger plots using bollinger data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 857 entries, 0 to 856
# Data columns (total 90 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Date                                                 857 non-null    datetime64[ns]
#  1   IXIC Open                                            857 non-null    float64
#  2   IXIC High                                            857 non-null    float64
#  3   IXIC Low                                             857 non-null    float64
#  4   IXIC Close                                           857 non-null    float64
#  5   IXIC Adj Close                                       857 non-null    float64
#  6   4 WEEKS BANK DISCOUNT                                851 non-null    float64
#  7   4 WEEKS COUPON EQUIVALENT                            851 non-null    float64
# ...

# %%
# Some of the analytics columns used the first 20 rows to collect a moving average so the first 20 rows have a lot of NaN, 
# I will remove them.

df1 = df[df['MACD'].notna()]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 824 entries, 33 to 856
# Data columns (total 90 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Date                                                 824 non-null    datetime64[ns]
#  1   IXIC Open                                            824 non-null    float64
#  2   IXIC High                                            824 non-null    float64
#  3   IXIC Low                                             824 non-null    float64
#  4   IXIC Close                                           824 non-null    float64
#  5   IXIC Adj Close                                       824 non-null    float64
#  6   4 WEEKS BANK DISCOUNT                                818 non-null    float64
#  7   4 WEEKS COUPON EQUIVALENT                            818 non-null    float64
# ...

# %%
df1 = df1.fillna(method = 'ffill')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 824 entries, 33 to 856
# Data columns (total 90 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Date                                                 824 non-null    datetime64[ns]
#  1   IXIC Open                                            824 non-null    float64
#  2   IXIC High                                            824 non-null    float64
#  3   IXIC Low                                             824 non-null    float64
#  4   IXIC Close                                           824 non-null    float64
#  5   IXIC Adj Close                                       824 non-null    float64
#  6   4 WEEKS BANK DISCOUNT                                824 non-null    float64
#  7   4 WEEKS COUPON EQUIVALENT                            824 non-null    float64
# ...

# %%
df1.GDP.unique()
# Out:
# array([      nan, 19636.731, 21362.428, 21704.706, 23046.934, 23550.42 ,
#        24349.121, 25248.476, 25723.941])

# %%
df = df1[df1['GDP'].notna()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 795 entries, 62 to 856
# Data columns (total 90 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Date                                                 795 non-null    datetime64[ns]
#  1   IXIC Open                                            795 non-null    float64
#  2   IXIC High                                            795 non-null    float64
#  3   IXIC Low                                             795 non-null    float64
#  4   IXIC Close                                           795 non-null    float64
#  5   IXIC Adj Close                                       795 non-null    float64
#  6   4 WEEKS BANK DISCOUNT                                795 non-null    float64
#  7   4 WEEKS COUPON EQUIVALENT                            795 non-null    float64
# ...

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#    index       Date    IXIC Open    IXIC High     IXIC Low   IXIC Close  \
# 0     62 2020-04-01  7459.500000  7566.370117  7301.979980  7360.580078
# 1     63 2020-04-02  7317.450195  7501.700195  7307.950195  7487.310059
# 2     64 2020-04-03  7477.270020  7518.720215  7288.109863  7373.080078
# 3     65 2020-04-06  7660.169922  7938.330078  7617.790039  7913.240234
# 4     66 2020-04-07  8129.990234  8146.430176  7881.220215  7887.259766
#
#    IXIC Adj Close  4 WEEKS BANK DISCOUNT  4 WEEKS COUPON EQUIVALENT  \
# 0     7360.580078                   0.03                       0.03
# 1     7487.310059                   0.09                       0.09
# 2     7373.080078                   0.09                       0.09
# 3     7913.240234                   0.09                       0.09
# 4     7887.259766                   0.09                       0.09
#
#    8 WEEKS BANK DISCOUNT  ...        SMA  BB Upper Band  BB Lower Band  \
# ...

# %%
df.to_csv('capstone3_data_clean.csv')
